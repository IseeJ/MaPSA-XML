# %% [markdown]
# # Dict2XML

# %%
with open('mapsa.txt') as file:
    mapsaraw = file.read()
    filename = mapsaraw.split(',')[1]
print(filename)

with open('35494_016_PSP_MANL.txt') as file:
    myfile = file.read()
    mylines = myfile.split('\n\n')
    del mylines[16]
# Out:
# 35494_016_PSP_MANL.txt

# %%
#get name label from a line
def getNameLabel(line):
    myelements = line.split(';')
    name = myelements[4][:6] + '_'+ myelements[4][6:8]
    row = myelements[4][-1:]
    col = myelements[5]
    coor = str(int(col)-9).zfill(2)
    if int(coor) < 0:
        col = abs(int(coor))
        coor =str(1)+str(col)
    return name+'_'+row+coor

def getPosn(line):
    myelements = line.split(';')
    MPArow, MPAcol = myelements[2], myelements[3][0:2]
    MPAcoor = MPArow+MPAcol
    
    if MPAcol == 'D1':
        MPAcoor_num = MPArow
    elif MPAcol == 'D2':
        MPAcoor_num = str(17-int(MPArow))
    return MPAcoor_num

# %%
#create dictionary
final_dict = {}
final_dict['PARTS'] = {}
final_dict['PARTS']['PART mode="auto"'] = {} #doesnt work
final_dict['PARTS']['PART mode="auto"']['KIND_OF_PART'] = 'MaPSA'
final_dict['PARTS']['PART mode="auto"']['NAME_LABEL'] = mapsaraw.split(',')[0]
final_dict['PARTS']['PART mode="auto"']['MANUFACTURER'] = 'AEMtec'
final_dict['PARTS']['PART mode="auto"']['LOCATION'] = 'AEMtec'
final_dict['PARTS']['PART mode="auto"']['VERSION'] = '2.0'

final_dict['PARTS']['PART mode="auto"']['CHILDREN'] ={}

# %%
#Add to child dictionary
def process(line):
    child = {}
    child['PART'] = {}
    child['PART']['KIND_OF_PART'] = 'MPA Chip'
    child['PART']['SERIAL_NUMBER'] = {}
    child['PART']['NAME_LABEL'] = getNameLabel(line)
    child['PART']['PREDEFINED_ATTRIBUTES'] = {}
    child['PART']['PREDEFINED_ATTRIBUTES']['ATTRIBUTE']= {}
    child['PART']['PREDEFINED_ATTRIBUTES']['ATTRIBUTE']['NAME'] = 'Chip Posn on Sensor'
    child['PART']['PREDEFINED_ATTRIBUTES']['ATTRIBUTE']['VALUE'] = getPosn(line)
    return child

# %%
from dict2xml import dict2xml


for line in mylines:
    final_dict['PARTS']['PART mode="auto"']['CHILDREN'] = process(line) 
    print(dict2xml(final_dict))
# Out:
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_506</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>1</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_505</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>16</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_504</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>2</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_503</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>15</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_502</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>3</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_501</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>14</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_500</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>4</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_511</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>13</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_512</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>5</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_513</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>12</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_514</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>6</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_515</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>11</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_516</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>7</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_517</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>10</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_518</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>8</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
# <PARTS>
#   <PART_mode__auto_>
#     <CHILDREN>
#       <PART>
#         <KIND_OF_PART>MPA Chip</KIND_OF_PART>
#         <NAME_LABEL>N6Y215_03_519</NAME_LABEL>
#         <PREDEFINED_ATTRIBUTES>
#           <ATTRIBUTE>
#             <NAME>Chip Posn on Sensor</NAME>
#             <VALUE>9</VALUE>
#           </ATTRIBUTE>
#         </PREDEFINED_ATTRIBUTES>
#         <SERIAL_NUMBER></SERIAL_NUMBER>
#       </PART>
#     </CHILDREN>
#     <KIND_OF_PART>MaPSA</KIND_OF_PART>
#     <LOCATION>AEMtec</LOCATION>
#     <MANUFACTURER>AEMtec</MANUFACTURER>
#     <NAME_LABEL>AEM_35494_016L</NAME_LABEL>
#     <VERSION>2.0</VERSION>
#   </PART_mode__auto_>
# </PARTS>
